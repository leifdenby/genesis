# %%
import genesis.objects.topology.plots.shapes
import matplotlib.pyplot as plt

import importlib
importlib.reload(genesis.objects.topology.plots.shapes)

# %matplotlib inline

shapes = genesis.objects.topology.plots.shapes
# Out:
# Using numpy.fft fallback

# %% [markdown]
# # 3D wireframe

# %%
shapes.spheroid_3d(radii=[10., 20., 50.], rotation=[0.0, 0.0], plot_axes=True, show_grid_axes=False)
# Out:
# <Axes3DSubplot:>

# %% [markdown]
# # Outline diagrams

# %%
fig, ax = plt.subplots()

shapes.spheroid(ax=ax, x_c=0.5, y_c=0.5, l=0.2, r=0.2, color="blue")
shapes.spheroid(ax=ax, x_c=0.8, y_c=0.8, l=0.1, r=0.2, color="red")
shapes.spheroid(ax=ax, x_c=0.2, y_c=0.5, l=0.3, r=0.2, color="green")
shapes.spheroid(ax=ax, x_c=0.8, y_c=0.2, l=0.3, r=0.1, color="orange")

# %%
fig, ax = plt.subplots()

shapes.spheroid(ax=ax, x_c=0.5, y_c=0.5, l=0.2, r=0.2, color="blue")
shapes.spheroid(ax=ax, x_c=0.5, y_c=0.5, l=0.5, r=0.3, color="orange")

# %%
fig, ax = plt.subplots()


shapes.spheroid(ax=ax, x_c=0.5, y_c=0.5, l=0.1, r=0.4, color="orange")

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect(1.0)

shapes.spheroid(ax=ax, x_c=0.25, y_c=0.5, l=0.2, r=0.2, color="orange")
shapes.spheroid(ax=ax, x_c=0.75, y_c=0.5, l=0.2, r=0.2, color="red", y_axis_3d_len=0.1)
